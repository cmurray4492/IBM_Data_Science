# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Craig Murray
# Director, Human Resources

# %% [markdown]
# I am intersted in Data Science because I want to apply it to Human Resources. While there has been work done in this field I think there is room for improvement and growth.

# %% [markdown]
# The code in cell 5 uses the print function to print "Hello, Data Science" Instead of Hello World!

# %%
print("Hello, IBM Data Science")
# Out:
# Hello, IBM Data Science

# %%
from IPython.core.display import HTML
HTML("<HR><ul><li>List Item 1</li><li>List Item 2 </li><li>List Item 3</li></ul><a href='http://google.com'>google</a>")
# Out:
# <HR><ul><li>List Item 1</li><li>List Item 2 </li><li>List Item 3</li></ul><a href='http://google.com'>google</a>
